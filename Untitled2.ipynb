# %%
while(1):
    frame=cap.read()
    #conver color frame to a gray frame
    gray_image=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    detections=face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=6) #mnsize,maxsize
    k=cv2.imread('path')
    ka=cv2.imread('path', cv2.IMREAD_UNCHANGED)
    for face in detections:
        x, y, w,h=face

        k1=cv2.resize(k, (w//3, h//3))
        ka1=cv2.resize(ka, (w//3, h//3))

        sy=y + h//2 - h//6
        sx=x + w//2 - w//6

        k1[:,:,0]=cv2.bitwise_and(k1[:,:,0], ka1[:,:,3])
        k1[:,:,1]=cv2.bitwise_and(k1[:,:,1], ka1[:,:,3])
        k1[:,:,2]=cv2.bitwise_and(k1[:,:,2], ka1[:,:,3])

        fa=frame[sy:sy+h//3, sx:sx+w//3,:]
        klm=cv2.bitwise_or(k1,fa)

        if y>100:
            frame[sy:sy+h//3,sx:sx+w//3]=klm

    cv2.imshow("Frame", frame)
    if cv2.waitKey(1) & 0xFF== ord('q'):
        break

cv2.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 while(1):
# ----> 2     frame=cap.read()
#       3     #conver color frame to a gray frame
#       4     gray_image=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cap' is not defined

# %%
import cv2

# Initialize the video capture object
cap = cv2.VideoCapture(0)  # Replace 0 with your camera index or video file path
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Load images
k = cv2.imread('/Users/niteshyadav/edge ai/football.jpg')  # Replace with the actual path to your image
ka = cv2.imread('/Users/niteshyadav/edge ai/cricket_ball.jpg', cv2.IMREAD_UNCHANGED)  # Replace with the actual path to your image with alpha channel

if k is None or ka is None:
    print("Error loading images.")
    cap.release()
    cv2.destroyAllWindows()
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture image")
        break

    # Convert the frame to grayscale
    gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale frame
    detections = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=6)

    for face in detections:
        x, y, w, h = face

        # Resize the overlay images to fit the face
        k1 = cv2.resize(k, (w//3, h//3))
        ka1 = cv2.resize(ka, (w//3, h//3))

        # Calculate positions
        sy = y + h//2 - h//6
        sx = x + w//2 - w//6

        # Apply the alpha mask
        k1[:, :, 0] = cv2.bitwise_and(k1[:, :, 0], ka1[:, :, 3])
        k1[:, :, 1] = cv2.bitwise_and(k1[:, :, 1], ka1[:, :, 3])
        k1[:, :, 2] = cv2.bitwise_and(k1[:, :, 2], ka1[:, :, 3])

        # Select the region of interest (ROI) from the frame
        fa = frame[sy:sy+h//3, sx:sx+w//3, :]

        # Overlay the image
        klm = cv2.bitwise_or(k1, fa)

        # Replace the ROI in the frame with the overlay
        if y > 100:
            frame[sy:sy+h//3, sx:sx+w//3] = klm

    # Display the resulting frame
    cv2.imshow("Frame", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 42
#      39 sx = x + w//2 - w//6
#      41 # Apply the alpha mask
# ---> 42 k1[:, :, 0] = cv2.bitwise_and(k1[:, :, 0], ka1[:, :, 3])
#      43 k1[:, :, 1] = cv2.bitwise_and(k1[:, :, 1], ka1[:, :, 3])
#      44 k1[:, :, 2] = cv2.bitwise_and(k1[:, :, 2], ka1[:, :, 3])
#
# IndexError: index 3 is out of bounds for axis 2 with size 3

# %%
import cv2

# Initialize the video capture object
cap = cv2.VideoCapture(0)  # Replace 0 with your camera index or video file path
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Load images
k = cv2.imread('/Users/niteshyadav/edge ai/football.jpg')  # Replace with the actual path to your image
ka = cv2.imread('/Users/niteshyadav/edge ai/cricket_ball.jpg', cv2.IMREAD_UNCHANGED)  # Replace with the actual path to your image with alpha channel

if k is None or ka is None:
    print("Error loading images.")
    cap.release()
    cv2.destroyAllWindows()
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture image")
        break

    # Convert the frame to grayscale
    gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale frame
    detections = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=6)

    for face in detections:
        x, y, w, h = face

        # Resize the overlay images to fit the face
        k1 = cv2.resize(k, (w//3, h//3))
        ka1 = cv2.resize(ka, (w//3, h//3))

        # Calculate positions
        sy = y + h//2 - h//6
        sx = x + w//2 - w//6

        # Check if the image has an alpha channel
        if ka1.shape[2] == 4:  # RGBA image
            # Apply the alpha mask
            k1[:, :, 0] = cv2.bitwise_and(k1[:, :, 0], ka1[:, :, 3])
            k1[:, :, 1] = cv2.bitwise_and(k1[:, :, 1], ka1[:, :, 3])
            k1[:, :, 2] = cv2.bitwise_and(k1[:, :, 2], ka1[:, :, 3])
        else:  # No alpha channel, just use the image as is
            print("Image does not have an alpha channel. Using the original image.")

        # Select the region of interest (ROI) from the frame
        fa = frame[sy:sy+h//3, sx:sx+w//3, :]

        # Overlay the image
        klm = cv2.bitwise_or(k1, fa)

        # Replace the ROI in the frame with the overlay
        if y > 100:
            frame[sy:sy+h//3, sx:sx+w//3] = klm

    # Display the resulting frame
    cv2.imshow("Frame", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# Image does not have an alpha channel. Using the original image.
# ...
